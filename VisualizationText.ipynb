# %% [markdown]
# <a href="https://colab.research.google.com/github/Taiba528/My-Python-World/blob/master/VisualizationText.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from wordcloud) (7.0.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from wordcloud) (1.18.4)

# %%
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
dir(WordCloud)
# Out:
# ['__array__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_generated',
#  '_draw_contour',
#  '_get_bolean_mask',
#  'fit_words',
#  'generate',
#  'generate_from_frequencies',
#  'generate_from_text',
#  'process_text',
#  'recolor',
#  'to_array',
#  'to_file',
#  'to_html',
#  'to_image']

# %%
text = "I am Taiba.I love Data Science"

# %%
wordcloud = WordCloud().generate(text)

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
def plot_wordcloud(wordcloud):
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
wordcloud =  WordCloud().generate(text)
plot_wordcloud(wordcloud)
wordcloud =  WordCloud(stopwords={'I','am'}).generate(text)
plot_wordcloud(wordcloud)

# %%
text = "I am Taiba.Taiba loves Data Science.Taiba loves Text Analytics & wordcloud"

# %%
wordcloud =  WordCloud(relative_scaling=1.0,
    stopwords={'am','I'}).generate(text)
plot_wordcloud(wordcloud)

# %%
nltk.download('inaugural')
# Out:
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Unzipping corpora/inaugural.zip.
# True

# %%
#Trump speech
from urllib.request import urlopen
response = urlopen('https://www.usatoday.com/story/news/politics/2017/02/28/trump-speech-exaggerations-omissions-facts/98549138/')
html = response.read()
print(len(html))
tokens = [tok for tok in html.split()]
# Out:
# 145987

# %%
#We clean it a bit
from bs4 import BeautifulSoup
print("Calling BS4")
soup = BeautifulSoup(html, 'html.parser')

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()
# Out:
# Calling BS4

# %%
#Get the token
tokens = [tok for tok in soup.get_text().split()]

# %%
print(tokens[0:100])
# Out:
# ["Trump's", 'speech:', 'Exaggerations,', 'omissions,', 'factsPolice', 'take', 'a', 'knee', 'in', 'solidarity', '🌙', '+', '📧', '=', '😏', 'How', 'did', 'we', 'get', 'here?', '100,000', 'livesSUBSCRIBE', 'NOWOnly', '$4.99', 'per', 'monthNews', 'Sports', 'Entertainment', 'Life', 'Money', 'Tech', 'Travel', "OpinionSubscribeTrump's", 'speech:', 'Exaggerations,', 'omissions,', 'factsDonovan', 'SlackUSA', 'TODAYPresident', 'Trump', 'has', 'been', 'pilloried', 'repeatedly', 'for', 'having', 'a', 'somewhat', 'tenuous', 'relationship', 'with', 'the', 'truth', 'as', 'fact-checkers', 'have', 'blasted', 'most', 'every', 'exaggeration', 'or', 'wrongheaded', 'assertion', 'he', 'has', 'made,', 'whether', 'as', 'a', 'candidate', 'or', 'now,', 'as', 'leader', 'of', 'the', 'free', 'world.Here’s', 'a', 'check', 'on', 'some', 'of', 'the', 'statements', 'he', 'proffered', 'Tuesday', 'in', 'his', 'first', 'address', 'to', 'a', 'joint', 'session', 'of', 'Congress:Swamp', 'draining“We', 'have']

# %%
def wordfreq (words):
    """Function to generated the frequency distribution of the
given text"""
    word_freq={}
    for tok in words:
        if tok.lower() in word_freq:
            word_freq [tok.lower()]+=1
        else:
            word_freq [tok.lower()]=1
    return word_freq

# %%
new_tokens = wordfreq(tokens)

# %%
import nltk
import operator
# %matplotlib inline
Freq_dist_nltk=nltk.FreqDist(tokens)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 581 samples and 981 outcomes>
# [('the', 50), ('a', 27), ('of', 26), ('for', 18), ('to', 16), ('on', 13), ('his', 12), ('in', 11), ('has', 11), ('and', 11), ('Trump', 10), ('is', 9), ('as', 8), ('he', 7), ('by', 7), ('from', 7), ('that', 5), ('it', 5), ('more', 5), ('all', 5), ('was', 5), ('did', 4), ('have', 4), ('lobbying', 4), ('foreign', 4)]

# %%
my_list = ['the','of','on','in','to','a','and','at','for','with','as','his','he','by']

# %%
my_list
# Out:
# ['the',
#  'of',
#  'on',
#  'in',
#  'to',
#  'a',
#  'and',
#  'at',
#  'for',
#  'with',
#  'as',
#  'his',
#  'he',
#  'by']

# %%
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
for item in my_list:
    stopwords.add(item)

# %%
#plot the word cloud
wordcloud = WordCloud(stopwords=stopwords, relative_scaling=1.0).generate(soup.get_text())
plot_wordcloud(wordcloud)

# %%
#Python.org
from urllib.request import urlopen
response = urlopen('http://python.org/')
html = response.read()

#We clean it a bit
from bs4 import BeautifulSoup
print("Calling BS4")
soup = BeautifulSoup(html, 'html.parser')

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract() 
    
#Get the token
tokens = [tok for tok in soup.get_text().split()]

#Plot frequency distributions
Freq_dist_nltk=nltk.FreqDist(tokens)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)

#Plot the word cloud
wordcloud = WordCloud(stopwords=stopwords, relative_scaling=1.0).generate(soup.get_text())
plot_wordcloud(wordcloud)
# Out:
# Calling BS4
# <FreqDist with 528 samples and 1004 outcomes>
# [('Python', 54), ('>>>', 24), ('and', 20), ('to', 16), ('the', 14), ('is', 13), ('for', 11), ('News', 11), ('Events', 11), ('of', 10), ('with', 9), ('Community', 9), ('#', 9), ('More', 9), ('PSF', 8), ('=', 8), ('a', 8), ('3', 8), ('in', 8), ('Software', 7), ('Docs', 6), ('Guide', 6), ('2020', 6), ('The', 5), ('Group', 5)]
