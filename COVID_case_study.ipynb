# %% [markdown]
# <a href="https://colab.research.google.com/github/Taiba528/My-Python-World/blob/master/COVID_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ec848be9-1026-4b2e-9433-52d796500ede" name="files[]" multiple disabled />
#      <output id="result-ec848be9-1026-4b2e-9433-52d796500ede">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid_confirmed_daily_updates.csv to covid_confirmed_daily_updates.csv

# %%
df = pd.read_csv("covid_confirmed_daily_updates.csv")
df.head()
# Out:
#         Country/Region  1/22/20  1/23/20  ...  3/16/20  3/17/20  3/18/20
# 0          Afghanistan        0        0  ...       21       22       22
# 1              Albania        0        0  ...       51       55       59
# 2              Algeria        0        0  ...       54       60       74
# 3              Andorra        0        0  ...        2       39       39
# 4  Antigua and Barbuda        0        0  ...        1        1        1
#
# [5 rows x 58 columns]

# %%
df.shape
# Out:
# (153, 58)

# %%
df[df['Country/Region']=='India']
# Out:
#    Country/Region  1/22/20  1/23/20  ...  3/16/20  3/17/20  3/18/20
# 63          India        0        0  ...      119      142      156
#
# [1 rows x 58 columns]

# %%
def cal_moving_avg(input_df, window=2):
    """Calculates Moving avg using the window size."""
    _df = input_df.rolling(window, axis=1).median()['3/10/20']
    
    return _df

def cal_ewma(input_df, comm=0.3):
    """Calculates the exp wighted moving average using the window size."""
    _df = input_df.ewm(com=comm).mean()['3/10/20']
    
    return _df

# %%
all_pred_df = pd.DataFrame()
all_pred_df_ew = pd.DataFrame()

# %%
for df in [df, grp_reco_data_df, grp_death_data_df]:
    _df = cal_moving_avg(df, window=2)
    ew_df = cal_ewma(df, comm=0.4)
    all_pred_df = pd.concat([all_pred_df, _df], axis=1)
    all_pred_df_ew = pd.concat([all_pred_df_ew, ew_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-758c5a87996d> in <module>()
# ----> 1 for df in [df, grp_reco_data_df, grp_death_data_df]:
#       2     _df = cal_moving_avg(df, window=2)
#       3     ew_df = cal_ewma(df, comm=0.4)
#       4     all_pred_df = pd.concat([all_pred_df, _df], axis=1)
#       5     all_pred_df_ew = pd.concat([all_pred_df_ew, ew_df], axis=1)
#
# NameError: name 'grp_reco_data_df' is not defined

# %%
all_pred_df.columns =['Confirmed', 'Recovered', 'Death']    
all_pred_df_ew.columns =['Confirmed', 'Recovered', 'Death']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2a4031764922> in <module>()
# ----> 1 all_pred_df.columns =['Confirmed', 'Recovered', 'Death']
#       2 all_pred_df_ew.columns =['Confirmed', 'Recovered', 'Death']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
# --> 183                 "values have {new} elements".format(old=old_len, new=new_len)
#     184             )
#     185
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 3 elements
